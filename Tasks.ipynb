# %% [markdown]
# # Tasks:
# ***

# %% [markdown]
# ![creative-tasks.jpg](attachment:creative-tasks.jpg)

# %% [markdown]
# ***

# %% [markdown]
# ## Task 1: Counts.
# ***

# %% [markdown]
# ![Count-640x355.jpg](attachment:Count-640x355.jpg)
# ***
# <br>

# %% [markdown]
# This first task is to create a dictionary from a given list, and to generate an accompanying value for each unique element that states the number of times that this element appears in the given list.

# %%
# First create a list of values:
A = [10, 20, 10, 30, 20, 10, 50, 50, 40, 10, 40]

# %% [markdown]
# [1]:ThisPointer.com: How to convert a list to dictionary: https://thispointer.com/python-how-to-convert-a-list-to-dictionary/

# %%
# Next step is to find the unique values within the list:
unique_values_A=[]
for i in A:
    if i not in unique_values_A:
        unique_values_A.append(i)
print(unique_values_A)
# Out:
# [10, 20, 30, 50, 40]

# %% [markdown]
# [2]: Infopedic Techie: Find the unique values in a list: https: //www.youtube.com/watch?v=7f2UJgig2yI
#
# <br>

# %% [markdown]
# The next step would seem to be to figure out how to count the number of instances of a given element in the list:

# %%
# Next we find a way of counting an element in the list:
count10 = 0

for i in A:
    if(i == 10):
     count10 = count10 + 1
print ("{}:{}".format(10, count10))
# Out:
# 10:4

# %% [markdown]
# [3]: SDET - QA Automation Techie: Frequently Asked Python Program 15: Count Occurrences of an element in a list: https://www.youtube.com/watch?v=Fc6OOmf3Hcs
#
# <br>

# %% [markdown]
# So from here we can see that there is an obvious initial solution to the problem, which is to repeat the above step for each unique element.

# %%
# Repeaet last step for each element

count10 = 0
count20 = 0
count30 = 0
count40 = 0
count50 = 0

for i in A:
    if(i == 10):
     count10 = count10 + 1
print ("{}:{}".format(10, count10))

for i in A:
    if(i == 20):
     count20 = count20 + 1
print ("{}:{}".format(20, count20))

for i in A:
    if(i == 30):
     count30 = count30 + 1
print ("{}:{}".format(30, count30))

for i in A:
    if(i == 40):
     count40 = count40 + 1
print ("{}:{}".format(40, count40))

for i in A:
    if(i == 50):
     count50 = count50 + 1
print ("{}:{}".format(50, count50))
# Out:
# 10:4
# 20:2
# 30:1
# 40:2
# 50:2

# %% [markdown]
# I would imagine, however, that this is the most tedious possible approach, and in the case of a larger list with more elements this might begin to become near impossible, and would also result in an extremely long piece of code.

# %% [markdown]
# From a bit more trawling of a variety of forums and tutorials I have found a way of creating a dictionary that gets us up to the next point, in which from just a few lines of code we have a dictionary of key elements, accompanied by an empty string. The next step is finding out how to pair the counted values from the above function to the key elements.

# %%
# Create empty dictionary
# populate dictionary with key elements and accompanying empty strings using for loop & '.update'

converted_dict = {}
for i in A:
    converted_dict.update({i:""})
print(converted_dict)
# Out:
# {10: '', 20: '', 30: '', 50: '', 40: ''}

# %% [markdown]
# [4]:medium.com: Create a dictionary from a list: https://medium.com/swlh/create-a-dictionary-from-a-list-65742246ab4b
#
# <br>

# %% [markdown]
# (I will just make a brief statement here to clarify that up until this point I had been labouring under the illusion that certain basic operators, (namely 'count' & 'set') were out of bounds for this module, and as a result had been trying to re-invent the wheel of sorts. I had been struggling to fit these alternative functions to fit the solution in an inumerate variety of failed permutations, but now that I have clarified that these operators do not fall under the criteria of "any module from the standard library1 or otherwise", I think the solution should be a bit more obvious. I will, however, leave the initial functions at least, in case there is any debate as to whether or not I suffered enough coming to a solution.)
# ***

# %% [markdown]
# ### Solution:

# %%
# Add A.count(i) to above function:
converted_dict = {}
for i in A:
    converted_dict.update({i:A.count(i)})
print(converted_dict)
# Out:
# {10: 4, 20: 2, 30: 1, 50: 2, 40: 2}

# %% [markdown]
# As it turns out, the count function did make the solution 'somewhat' easier to access.
# [4]

# %% [markdown]
# ***
# ### Testing:

# %% [markdown]
# Now to test this piece of code on other lists of various categories:

# %% [markdown]
# <br>

# %% [markdown]
# Strings:

# %%
# Test on a list of strings:

color_list = ['light blue', 'gold', 'silver', 'blue', 'gold', 'green', 'blue', 'green', 'light blue', 'black', 'gold',
              'red', 'light blue', 'light blue', 'silver', 'silver', 'black', 'silver', 'black', 'silver', 'gold', 'green',
              'green', 'black', 'silver', 'red', 'black', 'black', 'gold', 'light blue', 'gold', 'black', 'silver',
              'black', 'black', 'green', 'light blue', 'green', 'red', 'red', 'green', 'black', 'blue', 'red', 'gold',
              'light blue', 'red', 'light blue', 'blue', 'blue', 'blue', 'green', 'red', 'silver', 'blue', 'blue', 'green',
              'silver', 'blue', 'green', 'gold', 'blue', 'silver', 'red', 'light blue', 'red', 'gold', 'red', 'gold',
              'light blue']

converted_dictB = {}
for i in color_list:
    converted_dictB.update({i:color_list.count(i)})
print(converted_dictB)
# Out:
# {'light blue': 10, 'gold': 10, 'silver': 10, 'blue': 10, 'green': 10, 'black': 10, 'red': 10}

# %% [markdown]
# <br>

# %% [markdown]
# Boolean list:

# %%
boolean_list = [False, False, True, False, True, True, False, True]

converted_dictC = {}
for i in boolean_list:
    converted_dictC.update({i:boolean_list.count(i)})
print(converted_dictC)
# Out:
# {False: 4, True: 4}

# %% [markdown]
# <br>

# %% [markdown]
# Mixed:

# %%
# mixed list of variety of element types:

mixed_list = [False, False, True, False, True, True, False, True, 'green', 'light blue', 'green', 'red', 'red', 'green', 'black', 'blue', 'red', 'gold',
              'light blue', 'red', 'light blue', 'blue', 'blue', 'blue', 'green', 'red', 'silver', 'blue', 'blue', 'green',
              'silver', 'blue', 'green', 'gold', 'blue', 'silver', 'red', 'light blue', 'red', 'gold', 'red', 'gold',
              'light blue', 10, 20, 10, 30, 20, 10, 50, 50, 40, 10, 40]

converted_dictD = {}
for i in mixed_list:
    converted_dictD.update({i:mixed_list.count(i)})
print(converted_dictD)
# Out:
# {False: 4, True: 4, 'green': 6, 'light blue': 5, 'red': 8, 'black': 1, 'blue': 8, 'gold': 4, 'silver': 3, 10: 4, 20: 2, 30: 1, 50: 2, 40: 2}

# %% [markdown]
# <br>

# %% [markdown]
# Now that we have found the solution I am assuming I can use an internal module such as numpy to further test the function.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import csv

# %% [markdown]
# <br>

# %% [markdown]
# Floats:

# %%
rng = np.random.default_rng()
rng.random((50,))
# Out:
# array([0.05563799, 0.61167453, 0.21967728, 0.53076541, 0.51084644,
#        0.23664155, 0.61930129, 0.31575101, 0.75888132, 0.20626658,
#        0.4788568 , 0.97198907, 0.75987169, 0.24513541, 0.11251223,
#        0.38964866, 0.64182909, 0.81069019, 0.69007089, 0.94949644,
#        0.83212711, 0.75912661, 0.89479398, 0.64759039, 0.6887249 ,
#        0.91567021, 0.90610394, 0.22568548, 0.46932449, 0.30453743,
#        0.13097863, 0.73313528, 0.73328828, 0.29821759, 0.66682074,
#        0.46639015, 0.54949862, 0.75099475, 0.70071843, 0.7185181 ,
#        0.13871631, 0.79049043, 0.99826201, 0.86869032, 0.24050923,
#        0.41906783, 0.26459874, 0.18894941, 0.54409919, 0.25680243])

# %%
# Test on floats:

floats = [0.64402878, 0.97779973, 0.89163517, 0.31868202, 0.67386082,
       0.81886405, 0.34994059, 0.07856371, 0.21499661, 0.62535982,
       0.44242343, 0.34845095, 0.58239253, 0.11182759, 0.22644575,
       0.34676245, 0.69818649, 0.52299312, 0.16604863, 0.27448222,
       0.22078079, 0.07012799, 0.39442133, 0.54706702, 0.74630791,
       0.87477884, 0.87964366, 0.19449868, 0.00671595, 0.71740933,
       0.09978085, 0.07039272, 0.71411146, 0.41026414, 0.42353725,
       0.40925999, 0.27905673, 0.46817822, 0.16956298, 0.67811911,
       0.30974463, 0.2597022 , 0.39558906, 0.79048298, 0.83885269,
       0.45866721, 0.11566141, 0.64613368, 0.3181761 , 0.95404729]

converted_dictF = {}
for i in floats:
    converted_dictF.update({i:floats.count(i)})
print(converted_dictF)
# Out:
# {0.64402878: 1, 0.97779973: 1, 0.89163517: 1, 0.31868202: 1, 0.67386082: 1, 0.81886405: 1, 0.34994059: 1, 0.07856371: 1, 0.21499661: 1, 0.62535982: 1, 0.44242343: 1, 0.34845095: 1, 0.58239253: 1, 0.11182759: 1, 0.22644575: 1, 0.34676245: 1, 0.69818649: 1, 0.52299312: 1, 0.16604863: 1, 0.27448222: 1, 0.22078079: 1, 0.07012799: 1, 0.39442133: 1, 0.54706702: 1, 0.74630791: 1, 0.87477884: 1, 0.87964366: 1, 0.19449868: 1, 0.00671595: 1, 0.71740933: 1, 0.09978085: 1, 0.07039272: 1, 0.71411146: 1, 0.41026414: 1, 0.42353725: 1, 0.40925999: 1, 0.27905673: 1, 0.46817822: 1, 0.16956298: 1, 0.67811911: 1, 0.30974463: 1, 0.2597022: 1, 0.39558906: 1, 0.79048298: 1, 0.83885269: 1, 0.45866721: 1, 0.11566141: 1, 0.64613368: 1, 0.3181761: 1, 0.95404729: 1}

# %% [markdown]
# <br>
# As you can imagine, there isn't much obvious uses for this function when it comes to floats due to their near infinitely random nature. If you were to add a small line of code to spot duplicates, however, it may come in handy in the rare case of numbers repeating, perhaps in much larger lists:
#
# <br>

# %%
# Add if statement to test for duplicates
# Add duplicate number to demonstrate:

floats = [0.64402878, 0.97779973, 0.89163517, 0.31868202, 0.67386082,
       0.81886405, 0.34994059, 0.07856371, 0.21499661, 0.62535982,
       0.44242343, 0.34845095, 0.58239253, 0.11182759, 0.22644575,
       0.34676245, 0.69818649, 0.52299312, 0.16604863, 0.27448222,
       0.22078079, 0.07012799, 0.39442133, 0.54706702, 0.74630791,
       0.87477884, 0.87964366, 0.19449868, 0.19449868, 0.00671595, 0.71740933,
       0.09978085, 0.07039272, 0.71411146, 0.41026414, 0.42353725,
       0.40925999, 0.27905673, 0.46817822, 0.16956298, 0.67811911,
       0.30974463, 0.2597022 , 0.39558906, 0.79048298, 0.83885269,
       0.45866721, 0.11566141, 0.64613368, 0.3181761 , 0.95404729]

converted_dictF = {}
for i in floats:
    converted_dictF.update({i:floats.count(i)})
    if floats.count(i) > 1:
        print("Duplicates found:", i)
print(converted_dictF)
# Out:
# Duplicates found: 0.19449868
# Duplicates found: 0.19449868
# {0.64402878: 1, 0.97779973: 1, 0.89163517: 1, 0.31868202: 1, 0.67386082: 1, 0.81886405: 1, 0.34994059: 1, 0.07856371: 1, 0.21499661: 1, 0.62535982: 1, 0.44242343: 1, 0.34845095: 1, 0.58239253: 1, 0.11182759: 1, 0.22644575: 1, 0.34676245: 1, 0.69818649: 1, 0.52299312: 1, 0.16604863: 1, 0.27448222: 1, 0.22078079: 1, 0.07012799: 1, 0.39442133: 1, 0.54706702: 1, 0.74630791: 1, 0.87477884: 1, 0.87964366: 1, 0.19449868: 2, 0.00671595: 1, 0.71740933: 1, 0.09978085: 1, 0.07039272: 1, 0.71411146: 1, 0.41026414: 1, 0.42353725: 1, 0.40925999: 1, 0.27905673: 1, 0.46817822: 1, 0.16956298: 1, 0.67811911: 1, 0.30974463: 1, 0.2597022: 1, 0.39558906: 1, 0.79048298: 1, 0.83885269: 1, 0.45866721: 1, 0.11566141: 1, 0.64613368: 1, 0.3181761: 1, 0.95404729: 1}

# %% [markdown]
# <br>

# %% [markdown]
# CSV Files:

# %% [markdown]
# Finally testing on a 'csv' file will not garner any results due to their formatting regarding collumns etc., in spite of the fact that they are a list of values sepperated by commas in the same way a list is. You could find a way to convert a csv column or row into a list and analyse it as such, but for now I think that may be overkill here.
#
# [5]: DataEng Uncomplicated: CSV To Python List: https://www.youtube.com/watch?v=4mqyi8Vqk78
#
# <br>

# %%
dfrock = pd.read_csv("https://vincentarelbundock.github.io/Rdatasets/csv/DAAG/seedrates.csv")
dfrock
# Out:
#    Unnamed: 0  rate  grain
# 0           1    50   21.2
# 1           2    75   19.9
# 2           3   100   19.2
# 3           4   125   18.4
# 4           5   150   17.9

# %% [markdown]
# I have incuded an image of the test on a csv file as the error was disrupting the Flow of the cells running when the notebook was initialized.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <br>
# <br>
# <br>

# %% [markdown]
# #### Bibliography of some of the other sources used:
#
# * https://www.w3schools.com/: Python Dictionaries: https://www.w3schools.com/python/python_dictionaries.asp
# * Access 2 Learn: Counting with a while loop in Python: https://www.youtube.com/watch?v=GRiYD4g4O7I
# * ThisPointer.com: How to convert a list to dictionary: https://thispointer.com/python-how-to-convert-a-list-to-dictionary/
# * Data Science Tutorials: Python Dictionaries Tutorial 2: https://www.youtube.com/watch?v=gS-Dn7cCdok
# * Infopedic Techie: Find the unique values in a list: https: //www.youtube.com/watch?v=7f2UJgig2yI
# * Tech with Tim: Python programming tutorial #15: https://www.youtube.com/watch?v=W4JwgcqpDBE
# * DataEng Uncomplicated: CSV To Python List: https://www.youtube.com/watch?v=4mqyi8Vqk78
# * tutorialspoint.com: How to append objects in python: :https://www.tutorialspoint.com/How-to-append-objects-in-a-list-in-Python#:~:text=To%20add%20a%20single%20element,on%20which%20it%20is%20called.
# * stackoverflow.com: How to assign each element of a list to a seperate variable? :https://stackoverflow.com/questions/19300174/how-to-assign-each-element-of-a-list-to-a-separate-variable
# * https://dfrieds.com/: Count occurences of each unique element of a list:https://dfrieds.com/python/count-occurences-each-unique-element-in-list.html
# * medium.com: Create a dictionary froma list: https://medium.com/swlh/create-a-dictionary-from-a-list-65742246ab4b
# * Programiz: Python list: https://www.programiz.com/python-programming/list

# %% [markdown]
# <br>
# <br>
# <br>

# %% [markdown]
# ***

# %% [markdown]
# # Task 2: Dicerolls

# %% [markdown]
# ![Dice_1200_Social.jpg](attachment:Dice_1200_Social.jpg)

# %% [markdown]
# <br>

# %%
import numpy as np
import matplotlib.pyplot as plt
rng = np.random.default_rng()

# %% [markdown]
# <br>

# %% [markdown]
# First create a random number generateor that can simulate a single 6 sided die:

# %%
# Use rng.integers to generate a random number between 1 and 6:
die = rng.integers(1, 6)
die
# Out:
# 3

# %% [markdown]
# [6]: Numpy.org: Numpy.random.generator.choice: https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.choice.html#numpy.random.Generator.choice

# %% [markdown]
# <br>

# %% [markdown]
# As specified in the description of the task, create two variables, 'k' (Number of Dice) and 'n'(Number of rolls), and use these variables to generate an array of outcomes for each roll:
#
# As the aim is to focus on the sum of the outcomes, we have used the 'sum' opperator to add the outcome of any one set of dice being rolled together.

# %%
# The values 'k' & 'n' below can be changed to gain different results. 

# Create a varable 'k' to signify number of dice:
k = 7

# and a variable 'n' for number of times these dice are rolled
n = 500

# Input variables into die rng and add total of each roll together:
# This will generate an array of total values of all the dice rolled at any one time.

dicerolls = sum(rng.integers(1, 6, (k, n)))
dicerolls
# Out:
# array([26, 15, 31, 22, 26, 25, 24, 14, 22, 22, 23, 24, 26, 21, 22, 23, 13,
#        29, 18, 27, 12, 14, 18, 19, 25, 23, 16, 23, 21, 30, 23, 20, 27, 20,
#        21, 18, 19, 20, 13, 16, 18, 20, 25, 24, 21, 21, 21, 19, 16, 17, 19,
#        26, 17, 23, 22, 18, 24, 27, 25, 20, 25, 21, 27, 15, 25, 23, 24, 20,
#        20, 15, 17, 14, 23, 20, 19, 16, 21, 16, 23, 22, 21, 16, 16, 22, 23,
#        16, 16, 24, 20, 25, 18, 21, 22, 15, 23, 24, 16, 23, 14, 19, 16, 16,
#        16, 23, 15, 20, 20, 26, 27, 24, 25, 20, 26, 16, 19, 22, 17, 19, 21,
#        23, 20, 16, 18, 24, 20, 21, 23, 21, 18, 22, 23, 22, 22, 16, 13, 23,
#        26, 22, 22, 14, 22, 23, 20, 18, 19, 24, 16, 21, 18, 30, 24, 24, 25,
#        15, 17, 16, 18, 17, 22, 15, 18, 25, 19, 21, 28, 25, 21, 16, 22, 19,
#        26, 29, 23, 24, 20, 16, 22, 23, 16, 26, 19, 16, 24, 24, 22, 29, 23,
#        23, 19, 23, 18, 19, 24, 21, 20, 19, 18, 18, 16, 18, 27, 18, 22, 14,
# ...

# %% [markdown]
# [8]:geeksforgeeks.org: python progra to find sum of array: https://www.geeksforgeeks.org/python-program-to-find-sum-of-array/

# %% [markdown]
# [7]: Crash_Bandicode: My project on Numpy.Random for PFDA: https://github.com/Crash-Bandicode/numpy-random/blob/main/numpy.random.ipynb

# %% [markdown]
# <br>

# %%
# Convert resultant array to a list so that it can be converted into a dictionary.

arr = dicerolls
print(f'NumPy Array:\n{arr}')

list1 = arr.tolist()
print(f'List: {list1}')
# Out:
# NumPy Array:
# [26 15 31 22 26 25 24 14 22 22 23 24 26 21 22 23 13 29 18 27 12 14 18 19
#  25 23 16 23 21 30 23 20 27 20 21 18 19 20 13 16 18 20 25 24 21 21 21 19
#  16 17 19 26 17 23 22 18 24 27 25 20 25 21 27 15 25 23 24 20 20 15 17 14
#  23 20 19 16 21 16 23 22 21 16 16 22 23 16 16 24 20 25 18 21 22 15 23 24
#  16 23 14 19 16 16 16 23 15 20 20 26 27 24 25 20 26 16 19 22 17 19 21 23
#  20 16 18 24 20 21 23 21 18 22 23 22 22 16 13 23 26 22 22 14 22 23 20 18
#  19 24 16 21 18 30 24 24 25 15 17 16 18 17 22 15 18 25 19 21 28 25 21 16
#  22 19 26 29 23 24 20 16 22 23 16 26 19 16 24 24 22 29 23 23 19 23 18 19
#  24 21 20 19 18 18 16 18 27 18 22 14 22 23 22 12 26 22 22 25 23 16 26 21
#  21 25 24 16 21 26 20 19 26 19 21 27 24 18 15 24 18 21 25 21 14 27 22 20
#  24 26 23 22 17 29 15 18 20 19 18 17 25 21 27 14 27 24 21 23 29 19 21 20
#  20 21 20 25 17 26 15 15 20 19 23 21 14 19 23 22 22 29 22 18 22 16 17 18
#  26 15 23 23 15 25 19 18 22 23 28 20 22 23 20 20 23 14 23 26 21 22 20 25
# ...

# %% [markdown]
# [9]:JournalDev.com: Convert numpy array to list: https://www.journaldev.com/32797/python-convert-numpy-array-to-list

# %% [markdown]
# <br>

# %%
# Put list in order to un-jumble dictionary output:

list1.sort()

# %% [markdown]
# [10]: Geeksforgeeks.org: Python list sort: https://www.geeksforgeeks.org/python-list-sort/

# %% [markdown]
# <br>

# %%
# Using the function from the previous task we can create a dictionary:

roll_dict = {}
for i in list1:
    roll_dict.update({i:list1.count(i)})
print(roll_dict)
# Out:
# {10: 1, 11: 1, 12: 3, 13: 3, 14: 14, 15: 17, 16: 36, 17: 25, 18: 35, 19: 33, 20: 45, 21: 55, 22: 52, 23: 53, 24: 34, 25: 34, 26: 24, 27: 16, 28: 6, 29: 9, 30: 3, 31: 1}

# %% [markdown]
# [10]: Task 1: counts: This Paper: http://localhost:8888/notebooks/Tasks.ipynb#Task-2:-Dicerolls

# %% [markdown]
# Now that we have our dictionary we can use basic dictionary operations on our data to find any information we need. In the case of a very large dictionary, the '.get()' function could be very useful:

# %%
# use get operator to find out how many instances of a key there are in the list.

roll_dict.get(24)
# Out:
# 34

# %%
# We can remove certain elements from the dictionary using '.pop'

roll_dict.pop(11)
# Out:
# 1

# %%
# As you can see, '11' is now removed from the list of keys.

print(roll_dict)
# Out:
# {10: 1, 12: 3, 13: 3, 14: 14, 15: 17, 16: 36, 17: 25, 18: 35, 19: 33, 20: 45, 21: 55, 22: 52, 23: 53, 24: 34, 25: 34, 26: 24, 27: 16, 28: 6, 29: 9, 30: 3, 31: 1}

# %% [markdown]
# [11]: www.w3schools.com: Pyton Dictionary Methods: https://www.w3schools.com/python/python_ref_dictionary.asp

# %% [markdown]
# <br>
# <br>
# <br>

# %% [markdown]
# <br>
# <br>
# <br>

# %% [markdown]
# ***

# %% [markdown]
# ## Task 3: Binomial Function of a Coin:

# %% [markdown]
# ![Binomial-distribution-with-n-300-and-p-02-red-p-05-green-p-07-blue%20%281%29.png](attachment:Binomial-distribution-with-n-300-and-p-02-red-p-05-green-p-07-blue%20%281%29.png)

# %% [markdown]
# ***

# %% [markdown]
# #### Description of task:
#  "Write some python code that
# simulates flipping a coin 100 times. Then run this code 1,000 times, keeping track
# of the number of heads in each of the 1,000 simulations. Select an appropriate
# plot to depict the resulting list of 1,000 numbers, showing that it roughly follows
# a bell-shaped curve."

# %%
import numpy as np
import matplotlib.pyplot as plt
rng = np.random.default_rng()

# %% [markdown]
# <br>

# %% [markdown]
# In our other module 'Programming for Data Analytics' we were given an assignment in which we were to investigate the Numpy.Random module in python. In that investigation I discussed several probability distributions, one of which was the binomial distribution.
# As a result I will quote some of the project from that module here and  will include some of the same references I used for that project as well, as they are equally applicable.

# %% [markdown]
# "- "The Bernoulli distribution represents the success or failure of a single Bernoulli trial"

# %% [markdown]
# - ie: Likelihood of coin flip has an even distribution = 0.5/0.5, but the likelihood of rolling a six on a die would be 0.17 success/0.83 failure.
# - "The Binomial Distribution represents the number of successes and failures in n number of independent Bernoulli trials for some given value of n." [5]
# - It is basically a probability of probabilities, ie: the success rate or the likeliehood of a specific set of outcomes occuring vs other possible outcomes
# - It is useful when deling with uncertainty regarding a long run frequency." [7]

# %% [markdown]
# [12] Why is a binomial distribution bell-shaped? https://stats.stackexchange.com/questions/176425/why-is-a-binomial-distribution-bell-shaped

# %% [markdown]
# "- An example of this would be if a car manufacturer has a 0.13 percent chance of producing a faulty model, the binomial distribution would describe the most likely number of cars that would be faulty if the manufacturer made 10,000 cars. It doesn't guarantee the outcome will be 1300, but it tells you the probability of that outcome. It will also tell you the probability of the number being higher or lower.

# %% [markdown]
# •	Basically the distibution will run a number of bernoulli trialls and return a success rate for a given outcome." [7]

# %% [markdown]
# [13] 3Blue1Brown: Binomial distributions | Probabilities of probabilities, part 1 https://www.youtube.com/watch?v=8idr1WZ1A7Q
# ***

# %% [markdown]
# <br>
# Here we have number of coin flips - 'n'(100), and the probability of getting a heads - p(0.5)
#
# <br>
#
# Then we put those conditions into the Numpy.random.binomial function for it to run this test 1000 times, giving us an array of 1000 outcomes as follows:

# %%
#create variables to simulate 100 coin flips and use binomial to run test 1000 times.
coin = n, p = 100, 0.5
flips = rng.binomial(n, p, 1000)
flips
# Out:
# array([50, 45, 53, 47, 45, 44, 41, 48, 46, 59, 43, 48, 59, 48, 49, 43, 53,
#        58, 54, 48, 46, 57, 43, 50, 53, 47, 56, 56, 52, 51, 54, 60, 55, 45,
#        51, 55, 43, 52, 52, 52, 47, 59, 51, 49, 46, 51, 51, 48, 54, 48, 53,
#        55, 56, 49, 56, 49, 48, 43, 50, 44, 48, 47, 53, 62, 54, 47, 45, 44,
#        47, 43, 47, 52, 47, 51, 36, 55, 50, 47, 52, 53, 47, 52, 54, 44, 54,
#        42, 44, 45, 49, 53, 45, 47, 55, 56, 40, 46, 50, 53, 56, 45, 60, 43,
#        57, 45, 48, 56, 54, 46, 55, 56, 61, 44, 55, 47, 62, 44, 55, 47, 42,
#        55, 53, 51, 44, 43, 57, 45, 50, 56, 43, 41, 52, 42, 43, 54, 55, 50,
#        51, 48, 55, 41, 50, 50, 48, 58, 48, 52, 45, 47, 41, 50, 46, 53, 52,
#        51, 46, 39, 44, 59, 48, 51, 50, 54, 60, 46, 44, 47, 45, 58, 41, 58,
#        47, 50, 49, 47, 48, 52, 55, 54, 42, 43, 50, 62, 52, 54, 52, 53, 53,
#        51, 44, 59, 46, 53, 44, 59, 55, 45, 49, 49, 45, 56, 49, 57, 45, 45,
# ...

# %%
# Use histogram to show probability distribution:
plt.hist(flips)
# Out:
# (array([  5.,  21.,  59., 159., 198., 252., 172.,  92.,  31.,  11.]),
#  array([35. , 37.9, 40.8, 43.7, 46.6, 49.5, 52.4, 55.3, 58.2, 61.1, 64. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# As you can see, the probability of getting a specific result diminishes the further you move away from 50/100 in either direction, giving the histogram a bell shaped curve.

# %% [markdown]
# <br>
#
# <br>
#
# <br>

# %% [markdown]
# ***

# %% [markdown]
# ## Task 4: Simpson's Paradox:
# <br>

# %% [markdown]
# ![simpsons-paradox.jpg](attachment:simpsons-paradox.jpg)

# %% [markdown]
# ***
# <br>
# <br>

# %% [markdown]
# #### Description:
# "Use numpy to create four data sets, each with an x array
# and a corresponding y array, to demonstrate Simpson’s paradox."

# %% [markdown]
# - Before I begin I will just state that much of the process here was derived from the given lectures and my notes. A large amount of research was still required of course, however much of the process is owed to the fact that it was explained quite comprehensively already in the lectures, and thus did not require explicit research and references into every step.

# %%
# numerical array and fitting lines:
import numpy as np

# PLots
import matplotlib.pyplot as plt

# %%
# PLot style:
plt.style.use("ggplot")

# Larger plots:
plt.rcParams["figure.figsize"] = (20, 12)

# %% [markdown]
# 'Simpson' Paradox' is a term used in data analytics for a phenomenon that may occur when two or more similar datasets are combined, in which the original trends applied to both cause the new combined trend to become severely altered, or often fully inverted. Here we will explore why this occurs, what it means, and what it's implications may be in real life.

# %% [markdown]
# [14] Wikepedia: Simpson's paradox: https://en.wikipedia.org/wiki/Simpson%27s_paradox
#
# [15] Britanica.org: Simpson's Paradox Explained: https://www.britannica.com/topic/Simpsons-paradox
#
# [16] BMC Medical Research Methodology: https://bmcmedresmethodol.biomedcentral.com/articles/10.1186/1471-2288-8-34

# %% [markdown]
# The best way to illustrate the phenomenon is to create four sepperate scatter plots representing similar but different datasets. We can use the function of a line with added noise to reverse the concept of linear regression and simulate similar data sets of given trends. We will then combine the data sets and perform linear regression on the combined scatter plot in order to visualise the new trend created.

# %%
# create some x values:
x1 = np.linspace(0.0, 10.0, 100)
x2 = np.linspace(2.0, 12.0, 100)
x3 = np.linspace(4.0, 14.0, 100)
x4 = np.linspace(6.0, 16.0, 100)

# %%
# create some y values:
y1 = 2.0 * x1 + 1
y2 = 4.0 * x2 + 2
y3 = 6.0 * x3 + 3
y4 = 8.0 * x4 + 4

# %%
# plot first dataset
plt.plot(x1, y1)

# %% [markdown]
# Here we have plotted 100 points in a data set, all of which are joined by a straight line. Imagine that this was the line given by fitting the best possible line to a given data set. This would then be the 'trend' of the dataset. How then, can we simulate what that original dataset might look like? We can use noise to randomize the placement of the dots to a given degree so that the data looks like it may have been the origin of this trend.

# %%
# Add noise to our y values:
y1 = 2.0 * x1 + 1 + np.random.normal(0.0, 2, len(x1))
y2 = 4.0 * x2 + 2 + np.random.normal(0.0, 3, len(x2))
y3 = 6.0 * x3 + 3 + np.random.normal(0.0, 1, len(x3))
y4 = 8.0 * x4 + 4 + np.random.normal(0.0, 2, len(x4))

# %%
# plot first dataset with added noise:
plt.plot(x1, y1)

# %% [markdown]
# Here we get a line, so let's add dots instead:

# %%
# plot first dataset with added noise:
plt.plot(x1, y1, 'o')

# %% [markdown]
# Now, we know that the realtionship between x1 and y1 is characterised by the equation:
#
# - 'y1 = 2.0 * x1 + 1 + np.random.normal(0.0, 2, len(x1))'
#
# or in other words: y = mx + c (plus noise of course), with m & c being the coefficients (or parameters) of the equation, in the form of x^1 and x^0.
#
# What if we then asked numpy.polyfit to derive what it percieves to be the best trending line for these dots to be then:

# %%
# plot new coefficients based on noise generated dots:
coeffs1 = np.polyfit(x1, y1, 1)
coeffs1
# Out:
# array([1.9917353 , 1.27036797])

# %%
# plot the best fit line over the data points:
plt.plot(x1, y1, 'o', label="Data")
plt.plot(x1, coeffs1[0] * x1 + coeffs1[1], '-', label="Best fit")
plt.legend();

# %% [markdown]
# Now we can plot new coefficients for each of our other datasets:

# %%
# plot new coefficients for other y values:
coeffs2 = np.polyfit(x2, y2, 1)
coeffs2
# Out:
# array([3.92810992, 2.76324539])

# %%
# plot new coefficients:
coeffs3 = np.polyfit(x3, y3, 1)
coeffs3
# Out:
# array([6.02246588, 2.7765908 ])

# %%
# plot new coefficients:
coeffs4 = np.polyfit(x4, y4, 1)
coeffs4
# Out:
# array([8.00394827, 3.75192822])

# %% [markdown]
# And thus we can plot each data set in the same way as our first:

# %%
# plot the best fit line over the data points:
plt.plot(x2, y2, 'o', label="Data2")
plt.plot(x2, coeffs2[0] * x2 + coeffs2[1], '-', label="Best fit2")
plt.legend();

# %%
# plot the best fit line over the data points:
plt.plot(x3, y3, 'o', label="Data3")
plt.plot(x3, coeffs3[0] * x3 + coeffs3[1], '-', label="Best fit3")
plt.legend();

# %%
# plot the best fit line over the data points:
plt.plot(x4, y4, 'o', label="Data4")
plt.plot(x4, coeffs4[0] * x4 + coeffs4[1], '-', label="Best fit4")
plt.legend();

# %% [markdown]
# Now that we have all four data sets, we can combine their dat and plot them to the same graph. We can then see what affect this combining of data has on an overall best fit line. It is important to note that although the trends may be similar, they are not as closely related as they may seem in their respective graphs, as each plot has generated its own x and y axis to best represent that particular dataset, and thus the values represented are different respectively.

# %%
x = np.concatenate([x1, x2, x3, x4])

# %%
y = np.concatenate([y1, y2, y3, y4])

# %% [markdown]
# We can now find the coefficients of the combined datasets:

# %%
coeffs = np.polyfit(x, y, 1)
coeffs
# Out:
# array([  8.10999786, -17.31418232])

# %% [markdown]
# And thus we can now create our final graph:

# %%
# plot all 4 data sets, and combined data set best line:
plt.plot(x1, y1, 'o', label="Data")
plt.plot(x1, coeffs1[0] * x1 + coeffs1[1], '-', label="Best fit")
plt.plot(x2, y2, 'o', label="Data2")
plt.plot(x2, coeffs2[0] * x2 + coeffs2[1], '-', label="Best fit2")
plt.plot(x3, y3, 'o', label="Data3")
plt.plot(x3, coeffs3[0] * x3 + coeffs3[1], '-', label="Best fit3")
plt.plot(x4, y4, 'o', label="Data4")
plt.plot(x4, coeffs4[0] * x4 + coeffs4[1], '-', label="Best fit4")
plt.plot(x, y, 'o', label="Data Combined")
plt.plot(x, coeffs[0] * x + coeffs[1], '-', label="Best fit Combined")
plt.legend();

# %% [markdown]
# As we can see, the best fit line for the combined data doesn't really match any at all. If these lines were all parrallell, the best fit line would be the line perpendicular to all 4, meaniing it would intercept all four, but misrepresent all of them at any point other than the intercept. It is not as extreme here, but if you look at how independant the new line is from any of the dataset, it really does become obvious that it cannot be trusted to properly represent any of them.

# %% [markdown]
# So what are the implications of this experiment? Well, it proves that mixing the wrong data, even seemingly similar data, can generate serious misrepresentations within an analysis.
# <br>
#
# Not only can this lead to mistakes, it can also be utilised for more nefarious purposes, in which data can be skewed purposefully in order to achieve a desired result, rather than a true one.
# <br>
#
# This Statistical bias is described in the papers we studied in this course. It is explicitly mentioned in the Berkley study of admissions biases. If you consider how the pooling of all departments into one data pool skewed the results of individual departments admissions data, you could argue that it is a perfect example of Simpsons Paradox.
# <br>
#
# According to another study by Howard Wainer (listed below) regarding the test scores of different states, the test results are again skewed when pooled together. You could argue that because the average test score of a state is higher than that of another that it has a better education system, however this may not be the case. If factors such as socio-economic and racial factors are taken into account, we can say that a pool of mostly privelaged students would be expected to score higher, and less privelaged groups lower. If a state has more underprivelaged students, but their collecive test scores are higher than their underprivelaged counterparts in other states, the education system there must be doing a better job. Howevever, if said counterparts are mixed with a much larger pool of even mediocre privelaged students then the result may be skewed in favor of a state that is relying more on socio-economic privelages than it is on quality of education to raise its average.

# %% [markdown]
# [17] Simpson's paradox: https://www.youtube.com/watch?v=ebEkn-BiW5k
#
# <Br>
#
# [18] Journal of Educational Staistics: Howard Wainer: Minority contributions to the SAT score Turnaround: and Example of Simpson's paradox https://www.jstor.org/stable/1164696?seq=1#metadata_info_tab_contents
#
# <br>
#
# [19] Sex Bias In Graduation Admissions: Data from Berkely: P. J. Bickel, A. Hammel, J. W. O'Connell: https://learnonline.gmit.ie/pluginfile.php/231994/mod_resource/content/1/bickel-sex-bias-berkeley.pdf
